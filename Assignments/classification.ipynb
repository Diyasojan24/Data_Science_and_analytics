# %% [markdown]
# **LIBRARIES**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
lepath='/content/drive/MyDrive/ict academy/Dataset/iris.csv'
df_iris=pd.read_csv(lepath)
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#iris dataset is considered to be already preprocessed
#So only encoding is done
encoder=LabelEncoder()
df_iris['species']=encoder.fit_transform(df_iris['species'])
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# Model Building
#
# Logisticregression

# %%
#split data into traina and test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
X = df_iris.drop('species', axis=1)
y = df_iris['species']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
y_pred=log_reg.predict(X_test)
#evaluate the model
accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred,average='weighted')
recall=recall_score(y_test,y_pred,average='weighted')
print("Accuracy:",accuracy)
print("Precision:",precision)
print("Recall:",recall)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %%
#prediction using threshold
y_pred_threshold=log_reg.predict_proba(X_test)[:,1]
y_pred_threshold=(y_pred_threshold>0.33).astype(int)
#evaluate the model
accuracy_threshold=accuracy_score(y_test,y_pred_threshold)
precision_threshold=precision_score(y_test,y_pred_threshold,average='weighted')
recall_threshold=recall_score(y_test,y_pred_threshold,average='weighted')


print('Threshold value used=0.33')
print("Accuracy:",accuracy_threshold)
print("Precision:",precision_threshold)
print("Recall:",recall_threshold)
# Out:
# Threshold value used=0.33
# Accuracy: 0.7333333333333333
# Precision: 0.5511904761904761
# Recall: 0.7333333333333333
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **K-NN(K NEAREST NEIGHBOURS)**

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
#evaluate the model
accuracy=accuracy_score(y_test,y_pred)
precsiion=precision_score(y_test,y_pred,average='weighted')
recall=recall_score(y_test,y_pred,average='weighted')

print("Accuracy:",accuracy)
print("Precision:",precision)
print("Recall;",recall)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall; 1.0

# %% [markdown]
# **Naive-bayes classification**
#
# uses naive bayes'stheorem

# %%
nb_model=GaussianNB()
nb_model.fit(X_train,y_train)
y_pred_nb=nb_model.predict(X_test)
#evaluation
accuracy_nb=accuracy_score(y_test,y_pred_nb)
precision_nb=precision_score(y_test,y_pred_nb,average='weighted')
recall_nb=recall_score(y_test,y_pred_nb,average='weighted')
print("Accuracy:",accuracy_nb)
print("Precision:",precision_nb)
print("Recall:",recall_nb)
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9692307692307692
# Recall: 0.9666666666666667

# %% [markdown]
# SVM Classifier (Support vector Machine)

# %%
model = SVC(kernel='rbf')  # Can also use 'linear', 'poly'
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
svm_model=SVC()
svm_model.fit(X_train,y_train)
y_pred_svm=svm_model.predict(X_test)
#evaluation
accuracy_svm=accuracy_score(y_test,y_pred_svm)
precision_svm=precision_score(y_test,y_pred_svm,average='weighted')
recall_svm=recall_score(y_test,y_pred_svm,average='weighted')
confusion_matrix_svm=confusion_matrix(y_test,y_pred_svm)


print("Accuracy:",accuracy_svm)
print("Precision:",precision_svm)
print("Recall:",recall_svm)
print("Confusion Matrix:")
print(confusion_matrix_svm)
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9692307692307692
# Recall: 0.9666666666666667
# Confusion Matrix:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  1  7]]

# %% [markdown]
# Decision Tree

# %%
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train,y_train)
y_pred_dt=dt_model.predict(X_test)
#evaluation
accuracy_dt=accuracy_score(y_test,y_pred_dt)
precision_dt=precision_score(y_test,y_pred_dt,average='weighted')
recall_dt=recall_score(y_test,y_pred_dt,average='weighted')
confusion_matrix_dt=confusion_matrix(y_test,y_pred_dt)


print("Accuracy:",accuracy_dt)
print("Precision:",precision_dt)
print("Recall:",recall_dt)
print("Confusion Matrix:")
print(confusion_matrix_dt)
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9692307692307692
# Recall: 0.9666666666666667
# Confusion Matrix:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  1  7]]

# %% [markdown]
# Rndom Forest

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)
y_pred_rf=rf_model.predict(X_test)
#evaluation
accuracy_rf=accuracy_score(y_test,y_pred_rf)
precision_rf=precision_score(y_test,y_pred_rf,average='weighted')
recall_rf=recall_score(y_test,y_pred_rf,average='weighted')


print("Accuracy:",accuracy_rf)
print("Precision:",precision_rf)
print("Recall:",recall_rf)
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9692307692307692
# Recall: 0.9666666666666667

# %% [markdown]
# model comparison

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Support Vector Machine": SVC(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    results.append([name, accuracy, precision, recall, f1])

results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score"])
display(results_df)
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0     Logistic Regression  1.000000   1.000000  1.000000  1.000000
# 1     K-Nearest Neighbors  1.000000   1.000000  1.000000  1.000000
# 2             Naive Bayes  0.966667   0.969231  0.966667  0.966222
# 3  Support Vector Machine  0.966667   0.969231  0.966667  0.966222
# 4           Decision Tree  0.966667   0.969231  0.966667  0.966222
# 5           Random Forest  0.966667   0.969231  0.966667  0.966222
